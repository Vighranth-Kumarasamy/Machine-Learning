# %%
# CH.SC.U4CSE24149
# VIGHRANTH SK
# MACHINE LEARNING - ACTIVITY 9
# K NEAREST NEIGHBORS
# Exercise 2

import pandas as pd
import numpy as np

# 1. Create the dataset

data = {
    'Brightness': [40, 50, 60, 10, 70, 60, 25],
    'Saturation': [20, 50, 90, 25, 70, 10, 80],
    'Class': ['Red', 'Blue', 'Blue', 'Red', 'Blue', 'Red', 'Blue']
}

df = pd.DataFrame(data)

print("Dataset:")
print(df)

# 2. Define the new entry

new_brightness = 55
new_saturation = 60

print("\nNew Entry:")
print("Brightness:", new_brightness)
print("Saturation:", new_saturation)

# 3. Calculate Euclidean distance

df['Distance'] = np.sqrt(
    (df['Brightness'] - new_brightness) ** 2 +
    (df['Saturation'] - new_saturation) ** 2
)

# 4. Display the distances

print("\nEuclidean Distances:")
print(df[['Brightness', 'Saturation', 'Class', 'Distance']])

# 5. Find the nearest data point

nearest = df.loc[df['Distance'].idxmin()]

print("\nNearest Data Point:")
print(nearest)

# 6. Display the nearest class

print("\nNearest Class:", nearest['Class'])
# Out:
# Dataset:
#    Brightness  Saturation Class
# 0          40          20   Red
# 1          50          50  Blue
# 2          60          90  Blue
# 3          10          25   Red
# 4          70          70  Blue
# 5          60          10   Red
# 6          25          80  Blue
#
# New Entry:
# Brightness: 55
# Saturation: 60
#
# Euclidean Distances:
#    Brightness  Saturation Class   Distance
# 0          40          20   Red  42.720019
# 1          50          50  Blue  11.180340
# 2          60          90  Blue  30.413813
# 3          10          25   Red  57.008771
# 4          70          70  Blue  18.027756
# 5          60          10   Red  50.249378
# 6          25          80  Blue  36.055513
#
# Nearest Data Point:
# Brightness          50
# Saturation          50
# Class             Blue
# Distance      11.18034
# Name: 1, dtype: object
#
# Nearest Class: Blue
